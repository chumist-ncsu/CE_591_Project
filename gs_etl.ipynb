# %%
import gridstatus
import datetime as dt
import pandas as pd 
pd.Timestamp("2024-01-01")
# ercot = gridstatus.Ercot()
# Out:
# Timestamp('2024-01-01 00:00:00')

# %%
date = dt.date(2024, 1, 1)
ercot.get_load_by_weather_zone(date=pd.Timestamp("2024-01-01"))
# Out:
# 2025-10-08 11:19:49 - INFO - Fetching document https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13101&_1759936789
# 2025-10-08 11:19:49 - INFO - Requesting https://www.ercot.com/misapp/servlets/IceDocListJsonWS?reportTypeId=13101&_1759936789 with {}
# ---------------------------------------------------------------------------
# NoDataFoundException                      Traceback (most recent call last)
# Cell In[24], line 2
#       1 date = dt.date(2024, 1, 1)
# ----> 2 ercot.get_load_by_weather_zone(date=pd.Timestamp("2024-01-01"))
#
# File c:\Users\Chase Humiston\AppData\Local\Programs\Python\Python312\Lib\site-packages\gridstatus\decorators.py:133, in support_date_range.__call__.<locals>.wrapped_f(*args, **kwargs)
#     131 # no date range handling required
#     132 if "end" not in args_dict:
# --> 133     df = f(**args_dict)
#     134     _handle_save_to(df, save_to, args_dict, f)
#     135     return df
#
# ...

# %%
date.str()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 date.str()
#
# AttributeError: 'datetime.date' object has no attribute 'str'
